# %%
import sys

print ('Number of arguments:', len(sys.argv), 'arguments.')
print ('Argument List:', str(sys.argv))

if len(sys.argv) == 1 :
	print ("No command line argument" )
else:
	print("There is indeed command line argument " )

print ("End of Program " )
# Out:
# Number of arguments: 3 arguments.
# Argument List: ['C:\\ProgramData\\Anaconda3\\lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\HP\\AppData\\Roaming\\jupyter\\runtime\\kernel-31678d7a-b5b0-47aa-a705-39c3fb405387.json']
# There is indeed command line argument
# End of Program

# %%
import sys
from sys import exit



if len(sys.argv) == 1 :
	print ("No command line argument" )
	sys.exit()
#else :
#        print ("rest of the program ")

#numbers = sys.argv[1:]
#print (sorted(numbers, key=lambda x: float(x)))

numbers = []

i=1
n= len(sys.argv)

while ( i < n ):
	numbers.append(sys.argv[i])
	i=i+1

# bubbleSort(numbers)

n = len(numbers)
 
    # Traverse through all array elements
for i in range(n):
 
 # Last i elements are already in place
	for j in range(0, n-i-1):
 
            # traverse the array from 0 to n-i-1
            # Swap if the element found is greater
            # than the next element
            if numbers[j] > numbers[j+1] :
                numbers[j], numbers[j+1] = numbers[j+1], numbers[j]



print(numbers)

# %%
import sys
from sys import exit

def bubbleSort(arr):
    n = len(arr)
 
    # Traverse through all array elements
    for i in range(n):
 
        # Last i elements are already in place
        for j in range(0, n-i-1):
 
            # traverse the array from 0 to n-i-1
            # Swap if the element found is greater
            # than the next element
            if arr[j] > arr[j+1] :
                arr[j], arr[j+1] = arr[j+1], arr[j]




if len(sys.argv) == 1 :
	print ("No command line argument" )
	sys.exit()
#else :
#        print ("rest of the program ")

#numbers = sys.argv[1:]
#print (sorted(numbers, key=lambda x: float(x)))

numbers = []

i=1
n= len(sys.argv)

while ( i < n ):
	numbers.append(sys.argv[i])
	i=i+1

bubbleSort(numbers)




print(numbers)

# %%
import sys
from sys import exit

fn = lambda x, y, _sorted: [x, y, _sorted] if x < y else [y, x, False]

def bubbleSort(arr,f):
    n = len(arr)
 
    # Traverse through all array elements
    for i in range(n):
        _sorted = True
        # Last i elements are already in place
        for j in range(0, n-i-1):
 
            # traverse the array from 0 to n-i-1
            # Swap if the element found is greater
            # than the next element
            arr[j], arr[j + 1], _sorted = f(arr[j], arr[j + 1], _sorted)




if len(sys.argv) == 1 :
	print ("No command line argument" )
	sys.exit()
#else :
#        print ("rest of the program ")

#numbers = sys.argv[1:]
#print (sorted(numbers, key=lambda x: float(x)))

numbers = []

i=1
n= len(sys.argv)

while ( i < n ):
	numbers.append(sys.argv[i])
	i=i+1

bubbleSort(numbers,fn)




print(numbers)
